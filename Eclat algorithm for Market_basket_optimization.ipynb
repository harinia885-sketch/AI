# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r'C:\Users\harin\Downloads\Market_Basket_Optimisation.csv',header=None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
transactions=[]
for i in range(0,len(df)):
    transactions.append([str(df.values[i,j]) for j in range(0,20) if str(df.values[i,j])!='nan'])

# %%
transactions
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
min_support = 2

# Create vertical format
tid_sets = {}

for tid, transaction in enumerate(transactions, start=1):
    for item in transaction:
        if item not in tid_sets:
            tid_sets[item] = set()
        tid_sets[item].add(tid)

# %%
print("Vertical Format:")
for item, tids in tid_sets.items():
    print(item, ":", tids)
# Out:
# Vertical Format:
# ...

# %%
print("\nFrequent Itemsets:")

# Single items
for item, tids in tid_sets.items():
    if len(tids) >= min_support:
        print((item,), "Support =", len(tids))
# Out:
# Frequent Itemsets:
# ('shrimp',) Support = 536
# ('almonds',) Support = 153
# ('avocado',) Support = 250
# ('vegetables mix',) Support = 193
# ('green grapes',) Support = 68
# ('whole weat flour',) Support = 70
# ('yams',) Support = 86
# ('cottage cheese',) Support = 239
# ('energy drink',) Support = 200
# ('tomato juice',) Support = 228
# ('low fat yogurt',) Support = 574
# ('green tea',) Support = 991
# ('honey',) Support = 356
# ('salad',) Support = 37
# ('mineral water',) Support = 1788
# ('salmon',) Support = 319
# ('antioxydant juice',) Support = 67
# ('frozen smoothie',) Support = 475
# ('spinach',) Support = 53
# ('olive oil',) Support = 494
# ('burgers',) Support = 654
# ('meatballs',) Support = 157
# ('eggs',) Support = 1348
# ('chutney',) Support = 31
# ('turkey',) Support = 469
# ('milk',) Support = 972
# ('energy bar',) Support = 203
# ('whole wheat rice',) Support = 439
# ('whole wheat pasta',) Support = 221
# ('french fries',) Support = 1282
# ('soup',) Support = 379
# ...

# %%
from itertools import combinations
items = list(tid_sets.keys())

for item1, item2 in combinations(items, 2):
    common_tids = tid_sets[item1] & tid_sets[item2]

    if len(common_tids) >= min_support:
        print((item1, item2), "Support =", len(common_tids))
# Out:
# ('shrimp', 'almonds') Support = 17
# ('shrimp', 'avocado') Support = 23
# ('shrimp', 'vegetables mix') Support = 20
# ('shrimp', 'green grapes') Support = 8
# ('shrimp', 'whole weat flour') Support = 7
# ('shrimp', 'yams') Support = 8
# ('shrimp', 'cottage cheese') Support = 20
# ('shrimp', 'energy drink') Support = 21
# ('shrimp', 'tomato juice') Support = 27
# ('shrimp', 'low fat yogurt') Support = 47
# ('shrimp', 'green tea') Support = 86
# ('shrimp', 'honey') Support = 33
# ('shrimp', 'salad') Support = 6
# ('shrimp', 'mineral water') Support = 177
# ('shrimp', 'salmon') Support = 35
# ('shrimp', 'antioxydant juice') Support = 5
# ('shrimp', 'frozen smoothie') Support = 55
# ('shrimp', 'spinach') Support = 5
# ('shrimp', 'olive oil') Support = 61
# ('shrimp', 'burgers') Support = 66
# ('shrimp', 'meatballs') Support = 20
# ('shrimp', 'eggs') Support = 106
# ('shrimp', 'chutney') Support = 3
# ('shrimp', 'turkey') Support = 48
# ('shrimp', 'milk') Support = 132
# ...
