# %% [markdown]
# <a href="https://colab.research.google.com/github/harinia885-sketch/AI/blob/main/Neutal%20Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
import sklearn.datasets
from sklearn.model_selection import train_test_split
